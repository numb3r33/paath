# %%
#| hide
from paathai.core import *

# %% [markdown]
# # paath.ai
#
# > NLP library

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install paathai
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
